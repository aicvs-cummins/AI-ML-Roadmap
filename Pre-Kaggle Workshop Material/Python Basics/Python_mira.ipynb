# %%
#Matplotlib
# importing the required module

import matplotlib.pyplot as plt

# x axis values
x = [1,2,3]
# corresponding y axis values
y = [2,4,1]
# plotting the points
plt.plot(x, y)
# naming the x axis

plt.xlabel('x - axis')

# naming the y axis

plt.ylabel('y - axis')
# giving a title to the graph

plt.title('Graph')

# function to show the plot

plt.show()

# %%
#File Handling
#write mode
f=open("C:\\Users\\v_mir\\Desktop\\Mira\\mir_file.txt","w")
text="""Features of Python :
1. Easy to code.
2. High-Level Language.
3. Object-Oriented Methodology
4. Machine Learning"""
f.write(text)#writing text into file
f.flush()
f.close()

#read mode
f=open("C:\\Users\\v_mir\\Desktop\\Mira\\mir_file.txt","r")
print("-"*50)

print("Printing using for loop:\n")
for i in f:
 print(i)
print("-"*50)
f.close()
# Out:
# --------------------------------------------------
# Printing using for loop:
#
# Features of Python :
#
# 1. Easy to code.
#
# 2. High-Level Language.
#
# 3. Object-Oriented Methodology
#
# 4. Machine Learning
# --------------------------------------------------

# %%
f=open("C:\\Users\\v_mir\\Desktop\\Mira\\mir_file.txt","r")
print("Printing Course outcomes using readline() function:\n")
#reading text line by line
read=f.readline()
print(read)
read=f.readline()
print(read)
read=f.readline()
print(read)
print("-"*50)
f.close()
# Out:
# Printing Course outcomes using readline() function:
#
# Features of Python :
#
# 1. Easy to code.
#
# 2. High-Level Language.
#
# --------------------------------------------------

# %%
#append mode
f=open("C:\\Users\\v_mir\\Desktop\\Mira\\mir_file.txt","a")
append="\n5.Extensive array of libraries.\n6.Extremely Dynamic."
f.write(append)#appending text
print("Appended text : ",append)
f.close()

#read mode again
print("-"*50)
print("Reading after apending:\n")
f=open("C:\\Users\\v_mir\\Desktop\\Mira\\mir_file.txt","r")
read=f.read()
print(read)
print("-"*50)
# Out:
# Appended text :
# 5.Extensive array of libraries.
# 6.Extremely Dynamic.
# --------------------------------------------------
# Reading after apending:
#
# Features of Python :
# 1. Easy to code.
# 2. High-Level Language.
# 3. Object-Oriented Methodology
# 4. Machine Learning
# 5.Extensive array of libraries.
# 6.Extremely Dynamic.
# 5.Extensive array of libraries.
# 6.Extremely Dynamic.
# --------------------------------------------------

# %%
# Python program for creation of Arrays
import numpy as np

# Creating a rank 1 Array
a = np.array([1, 2, 3])
print("Array with Rank 1: \n",a)

# Creating a rank 2 Array
b = np.array([[1, 2, 3],
                [4, 5, 6]])
print("Array with Rank 2: \n", b)
# Out:
# Array with Rank 1:
#  [1 2 3]
# Array with Rank 2:
#  [[1 2 3]
#  [4 5 6]]

# %%
c = np.arange(100,120,2)
#The interval mentioned is half opened i.e. [Start,Stop)
print(c)
# Out:
# [100 102 104 106 108 110 112 114 116 118]

# %%
d = np.linspace(100,120,6)
#Interval [Start,Stop]
print(d)
# Out:
# [100. 104. 108. 112. 116. 120.]

# %%
#Pandas
import pandas as pd
import numpy as np

#Create Dataframe
df=pd.DataFrame(data=np.arange(0,20).reshape(5,4),index=["Row1","Row2","Row3","Row4","Row5"],columns=["Column1","Column2","Column3","Column4"])
df.head()
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df.tail(2)
# Out:
#       Column1  Column2  Column3  Column4
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df.describe()
# Out:
#          Column1    Column2    Column3    Column4
# count   5.000000   5.000000   5.000000   5.000000
# mean    8.000000   9.000000  10.000000  11.000000
# std     6.324555   6.324555   6.324555   6.324555
# min     0.000000   1.000000   2.000000   3.000000
# 25%     4.000000   5.000000   6.000000   7.000000
# 50%     8.000000   9.000000  10.000000  11.000000
# 75%    12.000000  13.000000  14.000000  15.000000
# max    16.000000  17.000000  18.000000  19.000000

# %%
df.isnull()
# Out:
#       Column1  Column2  Column3  Column4
# Row1    False    False    False    False
# Row2    False    False    False    False
# Row3    False    False    False    False
# Row4    False    False    False    False
# Row5    False    False    False    False

# %%
df['Column2'].unique()
# Out:
# array([ 1,  5,  9, 13, 17])

# %%
df['Column3'].value_counts()
# Out:
# Column3
# 2     1
# 6     1
# 10    1
# 14    1
# 18    1
# Name: count, dtype: int64
